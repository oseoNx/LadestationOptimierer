# %% [markdown]
# <p><span style="font-size:36px"><strong>2 Data Processing</strong></span></p>

# %%
import pandas as pd
import geopandas as gpd
import json as js
import numpy as np
import topojson as tp
import datetime
import shapely
from shapely import wkt
from shapely.wkb import loads, dumps
from shapely.geometry import Polygon, LineString, Point

# %% [markdown]
# <p><span style="font-size:18px"><strong>2.1 Elektroladestationen JSON in DataFrame umwandeln</strong></span></p>

# %% [markdown]
# Quelle: https://opendata.swiss/de/dataset/ladestationen-fuer-elektroautos/resource/4d467a51-0bc9-48ce-aa2a-3d3bcaa7e7e9

# %%
#JSON wird geladen
f = open('../Data/lade.json')
data = js.load(f)

# %%
#JSON wird in DF umgewandelt
OperatorNames = []
cities = []
plz = [] 
coords = []
for name in data['EVSEData']:
    for add in name['EVSEDataRecord']:
        OperatorNames.append(name['OperatorName'])
        cities.append(add['Address']['City'])
        plz.append(add['Address']['PostalCode'])
        coords.append(add['GeoCoordinates']['Google'])
        
d = {'OperatorName':OperatorNames,'City':cities,'Plz':plz,'Coord':coords}
df = pd.DataFrame(data=d)

# %%
#Koordinaten werden für spätere Schritte in zwei Spalten gesplittet
df['Lat']= df.apply(lambda x: x['Coord'].split(' ')[0], axis=1)
df['Lon']= df.apply(lambda x: x['Coord'].split(' ')[1],axis =1)

# %% [markdown]
# <p><span style="font-size:18px"><strong>2.2 Gemeindegrenzen richtig formattieren</strong></span></p>

# %% [markdown]
# Die Gemeindegrenzen wurden in einem vorherigen Schritt (siehe DataCollection Notebook) heruntergeladen. Jetzt gilt es die Daten in ein gängiges Format umzuwandeln, mit welchem die Grenzen richtig ausgelesen werden können. In dieser Domäne bietet sich ein GeoDF von GeoPandas sehr gut an, da GeoPandas viele Funktionen zum handeln von geografischen Daten besitzt.

# %%
gemdf = pd.read_csv('../Data/GemeindeGrenzen.csv')

# %% [markdown]
# Da Geopandas eine spezielle Formatierung braucht um die GeoDaten(MultiPolygone) als solche zu erkennen und es uns nicht gelungen ist diese korrekt einzulesen, werden Sie hier manuell in die korrekte Formatierung gebracht.

# %%
polytpl = []
for place in gemdf.Polygon:
    lst1 = [] 
    place = js.loads(str(place))['coordinates']
    for polobj in place:
        lst2 = []    
        for xobj in polobj:
            lst3 = []    
            for coordinates in xobj:
                   
                container = ''
                counter = 0
                for latlan in coordinates:
                    if counter == 1:
                        container += ' '
                    container += str(latlan)
                    counter +=1  
                lst3.append(container)
            lst2.append(tuple(lst3))
        lst1.append(tuple(lst2))
    polytpl.append(tuple(lst1))
polytpl = tuple((polytpl))

# %%
#Formatierung wird abgespeichert
gemdf['FormatPolygon'] = polytpl

# %%
#Daten werden weiter korrekt formatiert
gemdf['geometry'] = gemdf.apply(lambda x: str('MULTIPOLYGON' + str(x['FormatPolygon'])), axis = 1 )

# %%
#Daten werden zu ende formatiert und werden eingelesen
geometry_objects = [shapely.wkt.loads(str(s).replace("'",'').replace("),)",'))').replace(")),)",')))')) for s in gemdf.geometry]

# %%
#Daten werden als GeoPanda DF abgespeichert
geodf = gpd.GeoDataFrame(gemdf[['BFSid','GemeindeLabel']], geometry=gpd.GeoSeries(geometry_objects))

# %%
#Kontrolle
geodf
# Out:
#       BFSid       GemeindeLabel  \
# 0         1     Aeugst am Albis
# 1         2  Affoltern am Albis
# 2         3          Bonstetten
# 3         4     Hausen am Albis
# 4         5            Hedingen
# ...     ...                 ...
# 2143   6806        Vendlincourt
# 2144   6807       Basse-Allaine
# 2145   6808       Clos du Doubs
# 2146   6809         Haute-Ajoie
# 2147   6810          La Baroche
#
#                                                geometry
# 0     MULTIPOLYGON (((8.50389 47.27308, 8.50344 47.2...
# 1     MULTIPOLYGON (((8.41466 47.29360, 8.41496 47.2...
# 2     MULTIPOLYGON (((8.44132 47.31583, 8.44132 47.3...
# 3     MULTIPOLYGON (((8.57437 47.21707, 8.57434 47.2...
# 4     MULTIPOLYGON (((8.43621 47.31520, 8.43632 47.3...
# ...                                                 ...
# 2143  MULTIPOLYGON (((7.15253 47.43921, 7.15221 47.4...
# 2144  MULTIPOLYGON (((7.03694 47.49751, 7.03798 47.4...
# 2145  MULTIPOLYGON (((7.19091 47.34843, 7.19060 47.3...
# 2146  MULTIPOLYGON (((6.95744 47.40529, 6.95836 47.4...
# 2147  MULTIPOLYGON (((7.17671 47.38549, 7.17722 47.3...
#
# [2148 rows x 3 columns]

# %% [markdown]
# <p><span style="font-size:18px"><strong>2.3 Anzahl Elektroladestationen pro Gemeinde bestimmen</strong></span></p>

# %%
#DF wird auf korrektheit kontrolliert
df[df['OperatorName']=='eCarUp'].sort_values(by='Lat',ascending=True).head(60)
# Out:
#      OperatorName       City      Plz                  Coord         Lat  \
# 8463       eCarUp          -        -   -0.818855 -18.988678   -0.818855
# 9218       eCarUp          -        -   -0.818883 -18.971714   -0.818883
# 9610       eCarUp    WA 6056  Midvale  -31.892987 116.032476  -31.892987
# 8495       eCarUp  Vientiane        -   17.968313 102.612609   17.968313
# 8496       eCarUp  Vientiane        -   17.968313 102.612609   17.968313
# 9065       eCarUp          -        -   27.421028 -43.266836   27.421028
# 7234       eCarUp          -        -   28.841073 -43.272991   28.841073
# 7431       eCarUp          -        -    29.44057 -42.885544    29.44057
# 8921       eCarUp          -        -   29.675077 -42.238439   29.675077
# 7405       eCarUp          -        -   30.604648 -41.190937   30.604648
# 7622       eCarUp          -        -    30.69442 -43.177298    30.69442
# 7261       eCarUp          -        -   30.721918 -42.302593   30.721918
# 7532       eCarUp          -        -   31.104162 -43.280089   31.104162
# 8543       eCarUp          -        -     31.6038 -42.802441     31.6038
# 8374       eCarUp          -        -   31.936123 -42.103957   31.936123
# 8193       eCarUp          -        -   32.336719 -42.780024   32.336719
# 7196       eCarUp     קיסריה        -     32.484751 34.94486   32.484751
# 8357       eCarUp          -        -    32.643418 -39.74147   32.643418
# 7697       eCarUp          -        -   32.663589 -41.192381   32.663589
# 9118       eCarUp          -        -    32.77809 -41.720565    32.77809
# 8756       eCarUp          -        -    32.792078 -41.69635   32.792078
# 9499       eCarUp          -        -   32.952749 -41.918434   32.952749
# 7878       eCarUp          -        -   32.974499 -40.466315   32.974499
# 8684       eCarUp          -        -   33.287089 -41.126513   33.287089
# 9674       eCarUp          -        -   33.487555 -40.769991   33.487555
# 8400       eCarUp          -        -   33.523309 -42.166593   33.523309
# 7921       eCarUp          -        -   33.548733 -41.622471   33.548733
# 8238       eCarUp          -        -   33.552331 -39.793128   33.552331
# 9164       eCarUp          -        -   33.594902 -38.924468   33.594902
# 7569       eCarUp          -        -   33.621077 -40.765516   33.621077
# 8847       eCarUp          -        -   33.669859 -41.365476   33.669859
# 9822       eCarUp          -        -    33.67103 -41.339509    33.67103
# 9444       eCarUp          -        -   34.007374 -41.227676   34.007374
# 8509       eCarUp          -        -   34.060079 -40.220615   34.060079
# 8603       eCarUp          -        -   34.205021 -41.897973   34.205021
# 7334       eCarUp          -        -   34.325993 -40.796691   34.325993
# 8632       eCarUp          -        -    34.33887 -40.828954    34.33887
# 8090       eCarUp          -        -   34.360054 -40.788589   34.360054
# 8062       eCarUp          -        -   34.373599 -42.592817   34.373599
# 8712       eCarUp          -        -   34.507438 -40.982077   34.507438
# 9533       eCarUp          -        -   34.531061 -41.247887   34.531061
# 8253       eCarUp          -        -   34.550794 -41.918884   34.550794
# 8007       eCarUp          -        -   34.681679 -40.925683   34.681679
# 9376       eCarUp          -        -    34.69166 -41.080062    34.69166
# 8386       eCarUp     Tychon    Agios     34.71824 33.135155    34.71824
# 9797       eCarUp          -        -    34.77432 -40.969204    34.77432
# 8345       eCarUp          -        -   34.837053 -41.156186   34.837053
# 8934       eCarUp          -        -   34.839831 -39.375537   34.839831
# 8437       eCarUp          -        -     34.887097 -40.5922   34.887097
# 8013       eCarUp          -        -   34.963835 -40.846068   34.963835
# 9050       eCarUp          -        -    35.19899 -41.458045    35.19899
# 8095       eCarUp          -        -     35.305026 -38.7026   35.305026
# 9665       eCarUp          -        -   35.558801 -46.282041   35.558801
# 9763       eCarUp          -        -    35.58898 -42.826724    35.58898
# 9034       eCarUp          -        -    35.59586 -40.676935    35.59586
# 8514       eCarUp          -        -   36.364745 -39.069821   36.364745
# 7847       eCarUp          -        -   36.676897 -40.364909   36.676897
# 7982       eCarUp          -        -   36.872118 -42.416641   36.872118
# 9101       eCarUp          -        -   37.044332 -46.304449   37.044332
# 8709       eCarUp          -        -   37.163813 -41.129927   37.163813
#
#              Lon
# 8463  -18.988678
# 9218  -18.971714
# 9610  116.032476
# 8495  102.612609
# 8496  102.612609
# 9065  -43.266836
# 7234  -43.272991
# 7431  -42.885544
# 8921  -42.238439
# 7405  -41.190937
# 7622  -43.177298
# 7261  -42.302593
# 7532  -43.280089
# 8543  -42.802441
# 8374  -42.103957
# 8193  -42.780024
# 7196    34.94486
# 8357   -39.74147
# 7697  -41.192381
# 9118  -41.720565
# 8756   -41.69635
# 9499  -41.918434
# 7878  -40.466315
# 8684  -41.126513
# 9674  -40.769991
# 8400  -42.166593
# 7921  -41.622471
# 8238  -39.793128
# 9164  -38.924468
# 7569  -40.765516
# 8847  -41.365476
# 9822  -41.339509
# 9444  -41.227676
# 8509  -40.220615
# 8603  -41.897973
# 7334  -40.796691
# 8632  -40.828954
# 8090  -40.788589
# 8062  -42.592817
# 8712  -40.982077
# 9533  -41.247887
# 8253  -41.918884
# 8007  -40.925683
# 9376  -41.080062
# 8386   33.135155
# 9797  -40.969204
# 8345  -41.156186
# 8934  -39.375537
# 8437    -40.5922
# 8013  -40.846068
# 9050  -41.458045
# 8095    -38.7026
# 9665  -46.282041
# 9763  -42.826724
# 9034  -40.676935
# 8514  -39.069821
# 7847  -40.364909
# 7982  -42.416641
# 9101  -46.304449
# 8709  -41.129927

# %% [markdown]
# Wie man sehen kann gibt es gewisse Betreiber mit fehlerhafte Ladestationendaten, welche nicht in der Schweiz liegen. Zum Glück stimmen alle Koordinaten, weswegen man diese mit den Gemeindegrenzen abgleichen und die korrekte Gemeinde zuweisen kann.

# %%
#Koordinaten werden auf die Gemeinden abgegliechen und Gemeinde herausgesucht
ladeort = []
for x in range (0,df.shape[0]):
    try:
        ladeort.append(geodf[geodf.contains(Point(df['Lon'].iloc[x],df['Lat'].iloc[x]))]['GemeindeLabel'].values[0])
    except:
        ladeort.append(str('Error'))

# %%
#Die korrekten Gemeindebezeichnungen werden hinzugefügt
df['GemeindeLoc'] = ladeort

# %%
#Überblick über die falschen Daten und 'problematische' Betreiber, welche fehlerhafte Daten haben
df[(df['GemeindeLoc']=='Error') & (df['OperatorName']!='eCarUp')]
# Out:
#                         OperatorName      City   Plz  \
# 0     EWD Elektrizitätswerk Davos AG     Davos  7260
# 1     EWD Elektrizitätswerk Davos AG     Davos  7260
# 2     EWD Elektrizitätswerk Davos AG     Davos  7270
# 3     EWD Elektrizitätswerk Davos AG     Davos  7270
# 4     EWD Elektrizitätswerk Davos AG     Davos  7270
# ...                              ...       ...   ...
# 9852                         Fastned      Suhr  5034
# 9853                         Fastned  Lenzburg  5600
# 9854                         Fastned  Lenzburg  5600
# 9855                         Fastned  Lenzburg  5600
# 9856                         Fastned  Lenzburg  5600
#
#                            Coord                 Lat       Lon GemeindeLoc
# 0               46.81352 9.84591            46.81352   9.84591       Error
# 1                46.8135 9.84586             46.8135   9.84586       Error
# 2               46.80008 9.83121            46.80008   9.83121       Error
# 3     46.800129999999996 9.83124  46.800129999999996   9.83124       Error
# 4               46.79978 9.83104            46.79978   9.83104       Error
# ...                          ...                 ...       ...         ...
# 9852          47.380548 8.109115           47.380548  8.109115       Error
# 9853          47.392556 8.160158           47.392556  8.160158       Error
# 9854          47.392556 8.160158           47.392556  8.160158       Error
# 9855          47.392556 8.160158           47.392556  8.160158       Error
# 9856          47.392556 8.160158           47.392556  8.160158       Error
#
# [7148 rows x 7 columns]

# %%
#Der DF wird mit den korrekten Gemeinde IDs vom Bund (BFS-ID) versehen
BFSidlist = []
for x in range(0,df.shape[0]):
    try:
        BFSidlist.append(gemdf[gemdf['GemeindeLabel'] == df.GemeindeLoc.iloc[x]].BFSid.values[0])
    except:
        BFSidlist.append('NAN')

# %%
#Die BFS-ID werden hinzugefügt
df['BFSid'] = BFSidlist

# %%
#Das DF wird gecleaned. Nicht vorhandene Gemeinden (z. bsp. welche nicht in der Schweiz liegen werden gedroppt)
df = df.drop(df[df['BFSid'] == 'NAN'].index, axis=0)
df = df.drop(columns=['City','Plz','Coord'], axis=1)

# %%
geodf = geodf.merge(df.groupby('BFSid').count()['OperatorName'],how='left',on='BFSid')

# %%
#Ladestationen pro Gemeinde werden gezählt
geodf['AnzahlLadestation'] = geodf['OperatorName']
geodf['AnzahlLadestation'] = geodf['AnzahlLadestation'].fillna(0)
geodf = geodf.set_index('BFSid')
geodf = geodf.drop(columns='OperatorName', axis =1)

# %%
geodf.to_csv('../Data/LadestationProGemeinde.csv')

# %% [markdown]
# <p><span style="font-size:18px"><strong>2.4 Geodaten simplifizieren um Speicher/Leistung zu sparen </strong></span></p>

# %% [markdown]
# Da die Gemeindedaten sehr speicher intensiv sind und auf Streamlit mehr performance zum laden brauchen werden sie in den unteren Schritten vereinfacht. Die Vereinfachungsfunktion von GeoPandas vereinfacht leider nicht ohne dass Lücken zwischen den Gemeinden entstehen, so dass auf die topojson liabrary ausgewichen werden musste.

# %%
geodf_simple = tp.Topology(geodf, topology=True, toposimplify=0.001).to_gdf()

# %%
geodf_simple.to_csv('../Data/GemeindeGrenzen_Vereinfacht.csv')

# %% [markdown]
# <p><span style="font-size:18px"><strong>2.5 Ladestation Timeseries vorbereiten</strong></span></p>

# %% [markdown]
# Für die TimeSeries in unserer StreamlitApp bereiten wir hier die Daten in einer sogenannten 'geschmolzenen' Tabelle vor.<br /> Quelle: https://opendata.swiss/de/dataset/kennzahlen-offentliche-ladeinfrastruktur-elektromobilitat/resource/d772c474-e890-4de6-b1bb-416d90e860a3

# %%
ladstat = pd.read_csv('../Data/charging-infrastructure_key-figures.csv')

# %%
#Überblick Kolumnen
ladstat.columns.values
# Out:
# array(['year', 'month', 'chargingPower_10kW_count',
#        'chargingPower_21kW_count', 'chargingPower_42kW_count',
#        'chargingPower_100kW_count', 'chargingPower_100pluskW_count',
#        'chargingPower_AG_count', 'chargingPower_AG_sum',
#        'chargingPower_AI_count', 'chargingPower_AI_sum',
#        'chargingPower_AR_count', 'chargingPower_AR_sum',
#        'chargingPower_BE_count', 'chargingPower_BE_sum',
#        'chargingPower_BL_count', 'chargingPower_BL_sum',
#        'chargingPower_BS_count', 'chargingPower_BS_sum',
#        'chargingPower_CH_count', 'chargingPower_CH_sum',
#        'chargingPower_FR_count', 'chargingPower_FR_sum',
#        'chargingPower_GE_count', 'chargingPower_GE_sum',
#        'chargingPower_GL_count', 'chargingPower_GL_sum',
#        'chargingPower_GR_count', 'chargingPower_GR_sum',
#        'chargingPower_JU_count', 'chargingPower_JU_sum',
#        'chargingPower_LU_count', 'chargingPower_LU_sum',
#        'chargingPower_NE_count', 'chargingPower_NE_sum',
#        'chargingPower_NW_count', 'chargingPower_NW_sum',
#        'chargingPower_OW_count', 'chargingPower_OW_sum',
#        'chargingPower_SG_count', 'chargingPower_SG_sum',
#        'chargingPower_SH_count', 'chargingPower_SH_sum',
#        'chargingPower_SO_count', 'chargingPower_SO_sum',
#        'chargingPower_SZ_count', 'chargingPower_SZ_sum',
#        'chargingPower_TG_count', 'chargingPower_TG_sum',
#        'chargingPower_TI_count', 'chargingPower_TI_sum',
#        'chargingPower_UR_count', 'chargingPower_UR_sum',
#        'chargingPower_VD_count', 'chargingPower_VD_sum',
#        'chargingPower_VS_count', 'chargingPower_VS_sum',
#        'chargingPower_ZG_count', 'chargingPower_ZG_sum',
#        'chargingPower_ZH_count', 'chargingPower_ZH_sum',
#        'locations_AG_count', 'locations_AI_count', 'locations_AR_count',
#        'locations_BE_count', 'locations_BL_count', 'locations_BS_count',
#        'locations_CH_count', 'locations_FR_count', 'locations_GE_count',
#        'locations_GL_count', 'locations_GR_count', 'locations_JU_count',
#        'locations_LU_count', 'locations_NE_count', 'locations_NW_count',
#        'locations_OW_count', 'locations_SG_count', 'locations_SH_count',
#        'locations_SO_count', 'locations_SZ_count', 'locations_TG_count',
#        'locations_TI_count', 'locations_UR_count', 'locations_VD_count',
#        'locations_VS_count', 'locations_ZG_count', 'locations_ZH_count',
#        'plugs_AVCONConnector_count',
#        'plugs_CCSCombo1PlugCableAttached_count',
#        'plugs_CCSCombo2PlugCableAttached_count', 'plugs_CH_count',
#        'plugs_CHAdeMO_count', 'plugs_IEC60309SinglePhase_count',
#        'plugs_IEC60309ThreePhase_count',
#        'plugs_LargePaddleInductive_count', 'plugs_NEMA520_count',
#        'plugs_SmallPaddleInductive_count', 'plugs_TeslaConnector_count',
#        'plugs_Type1ConnectorCableAttached_count',
#        'plugs_Type2ConnectorCableAttached_count',
#        'plugs_Type2Outlet_count', 'plugs_Type3Outlet_count',
#        'plugs_TypeEFrenchStandard_count', 'plugs_TypeFSchuko_count',
#        'plugs_TypeGBritishStandard_count',
#        'plugs_TypeJSwissStandard_count', 'plugs_Unspecified_count',
#        'stations_AG_count', 'stations_AI_count', 'stations_AR_count',
#        'stations_BE_count', 'stations_BL_count', 'stations_BS_count',
#        'stations_CH_count', 'stations_FR_count', 'stations_GE_count',
#        'stations_GL_count', 'stations_GR_count', 'stations_JU_count',
#        'stations_LU_count', 'stations_NE_count', 'stations_NW_count',
#        'stations_OW_count', 'stations_SG_count', 'stations_SH_count',
#        'stations_SO_count', 'stations_SZ_count', 'stations_TG_count',
#        'stations_TI_count', 'stations_UR_count', 'stations_VD_count',
#        'stations_VS_count', 'stations_ZG_count', 'stations_ZH_count'],
#       dtype=object)

# %%
#Alle Kolumnen welche 'stations' enthalten sind für uns interessant. 
#Deswegen erstellen wir eine Liste mit diesen Kolumnen, welche wir nutzen werden um den DF zu filtern.
subs = 'stations'
res = [i for i in ladstat.columns.values if subs in i]
res.append('year')
res.append('month')
res

# %%
#Das gefilterte DF wird 'geschmolzen'
melted_df = ladstat[res].melt(id_vars=['year','month'],var_name='Canton',value_name='Amount')

# %%
#DF wird gecleaned
melted_df['Canton'] = melted_df.apply(lambda x: x['Canton'].replace('stations_','').replace('_count',''),axis=1)
melted_df['day'] = 1
melted_df['datetime'] = pd.to_datetime(melted_df[['year','month','day']])
melted_df = melted_df.drop(columns =['year','month','day'],axis=1)

# %%
#Kontrolle
melted_df
# Out:
#     Canton  Amount   datetime
# 0       AG     362 2020-11-01
# 1       AG     368 2020-12-01
# 2       AG     393 2021-01-01
# 3       AG     435 2021-02-01
# 4       AG     446 2021-03-01
# ..     ...     ...        ...
# 643     ZH    1102 2022-07-01
# 644     ZH    1151 2022-08-01
# 645     ZH    1086 2022-09-01
# 646     ZH    1090 2022-10-01
# 647     ZH    1103 2022-11-01
#
# [648 rows x 3 columns]

# %%
melted_df.to_csv('../Data/Chargingstations_melted.csv')
